# %% [markdown]
# What is this dataset about?
# this data set is about the employees and their salary
# Why is this analysis useful?
# this analysis is useful beacuse we can know the employees salary
# The goal is to understand salary distribution and departmental differences to support better decision-making.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("csv_file.csv")
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     object
#  1   Age         20 non-null     int64
#  2   Department  20 non-null     object
#  3   Salary      20 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 772.0+ bytes

# %% [markdown]
# this set is consist of 20 entries
# it contains 4 coloumns

# %%
df['Salary'].mean()
# Out:
# np.float64(73950.0)

# %%
df.groupby('Department')['Salary'].agg(['min','max'])
# Out:
#                min    max
# Department
# Engineering  75000  90000
# HR           55000  62000
# Marketing    79000  88000
# Sales        63000  72000

# %%
employee_count = df.groupby('Department')['Salary'].count()
employee_count.plot(kind='line')
plt.title("count of people")
plt.show()

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Engineering    81666.666667
# HR             58750.000000
# Marketing      83000.000000
# Sales          67800.000000
# Name: Salary, dtype: float64

# %% [markdown]
# Any imbalance between departments?
# we can see the grate imbalance between the  depatment through this data
# One recommendation to management
# management can approch opening for hr team
