# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("csv_file.csv")
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
avg_salary = df.groupby('Department')['Salary'].mean()
avg_salary.plot(kind='bar')
plt.title("Average Salary by Department")
plt.xlabel("Department")
plt.ylabel("Salary")
plt.show()

# %% [markdown]
# Engineering and marketing department has the highest average salary

# %%
df['Department'].value_counts().plot(kind='bar')
plt.title("Employee Count by Department")
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.show()

# %% [markdown]
# most employee work in engineering department

# %% [markdown]
# Did the chart make patterns clearer?
# yeah chart makes the patterns more clearer and its very usefull to be understand
# Which chart was more informative?
# the salary chart is more informative than the count
# Do visuals feel easier than raw numbers?
# yeah if feel more easier than the raw one
