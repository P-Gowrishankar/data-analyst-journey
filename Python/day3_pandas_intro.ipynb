# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# File ~\anacond\Lib\site-packages\pandas\__init__.py:49
#      46 # let init-time option registration happen
#      47 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 49 from pandas.core.api import (
#      50     # dtype
#      51     ArrowDtype,
#      52     Int8Dtype,
#      53     Int16Dtype,
#      54     Int32Dtype,
#      55     Int64Dtype,
#      56     UInt8Dtype,
#      57     UInt16Dtype,
#      58     UInt32Dtype,
#      59     UInt64Dtype,
#      60     Float32Dtype,
#      61     Float64Dtype,
#      62     CategoricalDtype,
#      63     PeriodDtype,
#      64     IntervalDtype,
#      65     DatetimeTZDtype,
#      66     StringDtype,
#      67     BooleanDtype,
#      68     # missing
#      69     NA,
# ...
