# %%
import math
numbers = [10,20,10,30,50,60,90,45,69,90]
length = len(numbers)
total = sum(numbers)
average = total/length

print(f"length of the list: {length}");
print(f"sum of the list :{total}");
print(f"average : {average}");

higher_than_average = [n]
for n in numbers:
    if n > average:
        higher_than_average.append(n)
print(f"number higher than the average: {higher_than_average}");
# Out:
# length of the list: 10
# sum of the list :474
# average : 47.4
# number higher than the average: [90, 50, 60, 90, 69, 90]

# %%
students = {
    "name":"yourname",
    "marks":[numbers]
}

# %%
for n in numbers:
    if n > 50:
        print(f"the mark {n}:pass");
    else :
        print(f"the mark {n}:fail");
# Out:
# the mark 10:fail
# the mark 20:fail
# the mark 10:fail
# the mark 30:fail
# the mark 50:fail
# the mark 60:pass
# the mark 90:pass
# the mark 45:fail
# the mark 69:pass
# the mark 90:pass

# %%
def max_min_function(numbers):
    return max(numbers), min(numbers)

max_value, min_value = max_min_function([10,20,5,40])

print(f"maximum:{max_value}")
print(f"minimum:{min_value}")
# Out:
# maximum:40
# minimum:5
