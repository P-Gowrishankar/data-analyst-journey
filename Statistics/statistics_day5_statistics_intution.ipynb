# %%
import pandas as pd
df = pd.read_csv(" csv file.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        20 non-null     object
#  1   Age         20 non-null     int64
#  2   Department  20 non-null     object
#  3   Salary      20 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 772.0+ bytes

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Department', 'Salary'], dtype='object')

# %%
df['Salary'].mean()
# Out:
# np.float64(73950.0)

# %% [markdown]
# this calculate the mean average

# %%
df['Salary'].median()
# Out:
# 76000.0

# %% [markdown]
# this shows the median value of the salary

# %%
df['Salary'].mode()
# Out:
# 0    79000
# Name: Salary, dtype: int64

# %%
it shows the most common value

# %%
df['Salary'].var
# Out:
# 114681578.94736843

# %% [markdown]
# In Pandas, df['Salary'].var() calculates the variance of the 'Salary' column in a DataFrame.

# %%
df['Salary'].std()
# Out:
# 10708.948545369356

# %% [markdown]
# calculates the sample standard deviation of the 'Salary' column in your DataFrame, measuring how spread out those salary values are from their average  square rooot of the varience

# %% [markdown]
# 1.statics the way of under standing the numbers
# 2.meaning of mean median and mode made me confusing
# 3.yes
